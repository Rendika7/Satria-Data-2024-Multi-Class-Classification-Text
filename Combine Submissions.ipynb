# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import re # if u want to learn regex [https://regex101.com/]
import string
import random # Random number generators - Library for generating random numbers, selecting random elements, shuffling sequences, etc.
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
# pd.set_option("display.max_row", None)

# %%
mainPath = "/content/drive/MyDrive/Colab Notebooks/2. Satria Data 2024/Pengerjaan Satria Data"
submissionsPath = os.path.join(mainPath, "/content/drive/MyDrive/Colab Notebooks/2. Satria Data 2024/Pengerjaan Satria Data/Submissions")

# %%
sub_45 = pd.read_csv(submissionsPath + "/[0.4521549475494896]-SD2024040000208.csv", sep=",")
sub_53 = pd.read_csv(submissionsPath + "/[0.5383940956785505]-SD2024040000208.csv", sep=",")
sub_62 = pd.read_csv(submissionsPath + "/[0.6275187883568056]-SD2024040000208.csv", sep=",")

# %%
sub_45.Kelas.value_counts()
# Out:
# Kelas
# Politik                    544
# Ekonomi                    133
# Pertahanan dan Keamanan    114
# Ideologi                    98
# Sosial Budaya               66
# Demografi                   25
# Sumber Daya Alam            15
# Geografi                     5
# Name: count, dtype: int64

# %%
sub_53.Kelas.value_counts()
# Out:
# Kelas
# Politik                    751
# Ekonomi                    110
# Pertahanan dan Keamanan     75
# Sosial Budaya               29
# Ideologi                    20
# Sumber Daya Alam            10
# Demografi                    3
# Geografi                     2
# Name: count, dtype: int64

# %%
sub_62.Kelas.value_counts()
# Out:
# Kelas
# Politik                    418
# Ekonomi                    158
# Pertahanan dan Keamanan    134
# Ideologi                   119
# Sosial Budaya               99
# Sumber Daya Alam            45
# Demografi                   24
# Geografi                     3
# Name: count, dtype: int64

# %%
sub_62
# Out:
#       IDText                    Kelas
# 0    TXT0001                  Politik
# 1    TXT0002  Pertahanan dan Keamanan
# 2    TXT0003                 Ideologi
# 3    TXT0004                  Politik
# 4    TXT0005                 Ideologi
# ..       ...                      ...
# 995  TXT0996                  Ekonomi
# 996  TXT0997                 Ideologi
# 997  TXT0998  Pertahanan dan Keamanan
# 998  TXT0999                  Ekonomi
# 999  TXT1000                  Politik
#
# [1000 rows x 2 columns]

# %%
sub_45
# Out:
#       IDText                    Kelas
# 0    TXT0001                  Politik
# 1    TXT0002  Pertahanan dan Keamanan
# 2    TXT0003                 Ideologi
# 3    TXT0004                  Politik
# 4    TXT0005                  Politik
# ..       ...                      ...
# 995  TXT0996                  Ekonomi
# 996  TXT0997                  Politik
# 997  TXT0998                  Politik
# 998  TXT0999                  Ekonomi
# 999  TXT1000                  Politik
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Combine

# %%
# Menggabungkan data berdasarkan IDText
merged_data = pd.merge(sub_45, sub_62, on='IDText', suffixes=('_sub_45', '_sub_62'))

# Inisialisasi list untuk menyimpan hasil zip
zipped_data = []

# Looping untuk bandingkan kelas dan hasilkan zip jika kelas sama
for index, row in merged_data.iterrows():
    if row['Kelas_sub_45'] == row['Kelas_sub_62']:
        zipped_data.append((row['IDText'], row['Kelas_sub_45']))
    else:
        zipped_data.append((row['IDText'], False))

# Buat DataFrame baru dari zipped_data
zipped_df = pd.DataFrame(zipped_data, columns=['IDText', 'Kelas_Zip'])

# %%
zipped_df.to_excel("zipped_df.xlsx", index=False)

# %%
id_texts = (zipped_df[zipped_df["Kelas_Zip"] == False]["IDText"]).tolist()

# %%
filtered_sub_45 = sub_45[sub_45['IDText'].isin(id_texts)]
filtered_sub_62 = sub_62[sub_62['IDText'].isin(id_texts)]

# %%
filtered_sub_45
# Out:
#       IDText          Kelas
# 4    TXT0005        Politik
# 7    TXT0008        Politik
# 12   TXT0013       Ideologi
# 13   TXT0014  Sosial Budaya
# 14   TXT0015        Politik
# ..       ...            ...
# 990  TXT0991        Politik
# 991  TXT0992        Politik
# 994  TXT0995  Sosial Budaya
# 996  TXT0997        Politik
# 997  TXT0998        Politik
#
# [309 rows x 2 columns]

# %%
filtered_sub_62
# Out:
#       IDText                    Kelas
# 4    TXT0005                 Ideologi
# 7    TXT0008  Pertahanan dan Keamanan
# 12   TXT0013  Pertahanan dan Keamanan
# 13   TXT0014                  Politik
# 14   TXT0015            Sosial Budaya
# ..       ...                      ...
# 990  TXT0991  Pertahanan dan Keamanan
# 991  TXT0992  Pertahanan dan Keamanan
# 994  TXT0995                 Ideologi
# 996  TXT0997                 Ideologi
# 997  TXT0998  Pertahanan dan Keamanan
#
# [309 rows x 2 columns]
